# %%
import numpy as np
import decimal
import matplotlib.pyplot as plt
import sympy as sp

# %%
def intializeContext(significantFigs,rounding) :
    #Intialize the context with specified signFigs and rounding/chopping
    decimal.getcontext().prec = significantFigs 
    if( rounding ) :
        decimal.getcontext().rounding = decimal.ROUND_HALF_UP
    else :
        decimal.getcontext().rounding = decimal.ROUND_DOWN

# %%
def parse_exp(expr_str , var_name='x') :
    x = sp.symbols(var_name)
    expr = sp.sympify(expr_str)
    
    def decimal_func(x_decimal) :
        if not isinstance(x_decimal,decimal.Decimal) :
            x_decimal = decimal.Decimal(x_decimal)
            
        result = expr.evalf(decimal.getcontext().prec,subs={x:x_decimal})
        return decimal.Decimal(str(result))
    
    return decimal_func

# %%
def parse_derivative(expr_str , var_name='x' ) :
    x = sp.symbols(var_name)
    expr = sp.sympify(expr_str)
    deriv = sp.diff(expr)
    
    def decimal_derv(x_decimal) :
        if not isinstance(x_decimal,decimal.Decimal) :
            x_decimal = decimal.Decimal(x_decimal)
        result = deriv.evalf(decimal.getcontext().prec,subs = {x:x_decimal})
        return decimal.Decimal(str(result))
    return decimal_derv

# %%
def ModifiedNewtonRaphson(x0, func_expr, tol=1e-7, max_iter=100,
                          significantFigs=14, rounding=True):
    """
    Modified Newton-Raphson method with second derivative correction.
    Uses the update formula:
    
        x_{n+1} = x_n - ( f(x_n) * f'(x_n) ) / ( (f'(x_n))^2 - f(x_n) * f''(x_n) )
    
    If the denominator becomes too small, the algorithm falls back
    to a standard Newton step: x_{n+1} = x_n - f(x_n) / f'(x_n).

    Returns:
        x_root        : final computed root
        relativeError : absolute error of last iteration
        num_iters     : number of iterations performed
        steps         : list of dictionaries with iteration history
    """

    # Set decimal precision and rounding mode
    intializeContext(significantFigs, rounding=rounding)

    # Convert initial guess to Decimal
    x_root = decimal.Decimal(x0)
    relativeError = decimal.Decimal("Infinity")

    # Parse function and derivatives
    func = parse_exp(func_expr)                   
    derivative = parse_derivative(func_expr)      

    # Build derivative expressions using sympy
    deriv_exp = str(sp.diff(sp.sympify(func_expr))) 
    d2_expr = str(sp.diff(sp.sympify(deriv_exp)))     
    second_derivative = parse_exp(d2_expr)          

    steps = []

    for i in range(max_iter):
        x_old = x_root

        # Evaluate f(x), f'(x), f''(x)
        fx = func(x_old)
        fpx = derivative(x_old)
        fppx = second_derivative(x_old)

        # Very small threshold to detect division issues
        eps = decimal.Decimal("1e-30")
        denominator = fpx**2 - fx * fppx

        # If denominator nearly zero → fallback to standard Newton step
        if abs(denominator) < eps:
            # Cannot proceed if derivative is zero
            if fpx == 0:
                break
            x_new = x_old - fx / fpx
        else:
            # Modified Newton–Raphson update
            x_new = x_old - (fx * fpx) / denominator

        # Compute absolute error
        if x_new != 0:
            relativeError = abs(x_new - x_old) / x_new
        else:
            relativeError = abs(x_old)

        # Save iteration information
        steps.append({
            "iter": i + 1,
            "x_old": x_old,
            "x_new": x_new,
            "error": relativeError
        })

        # Update current root estimate
        x_root = x_new

        # Stop if tolerance is satisfied
        if relativeError <= tol:
            break

    # Return results in the requested format
    return x_root, relativeError, len(steps), steps

# %%
x0 = 0.5
func_expr = "(x - 1)**3"

x_r, approx_error, num_iterations, steps = ModifiedNewtonRaphson(
    x0=x0,
    func_expr=func_expr,
    tol=1e-7,
    max_iter=20,
    significantFigs=14,
    rounding=True
)

print("Computed Root:", x_r)
print("approx_error: ", approx_error)
print("num_iterations: ", num_iterations)
for row in steps:
    print(row)
# Out:
# Computed Root: 1.0000000000000
# approx_error:  0
# num_iterations:  2
# {'iter': 1, 'x_old': Decimal('0.5'), 'x_new': Decimal('1.0'), 'error': Decimal('0.5')}
# {'iter': 2, 'x_old': Decimal('1.0'), 'x_new': Decimal('1.0000000000000'), 'error': Decimal('0')}

# %%
test_cases = [
    ("(x-1)**3", 0.5, 1),
    ("x**2 - 4", 3, 2),
    ("x**3 - 3*x**2 + 3*x - 1", 0, 1),
    ("x**3 + 2*x - 5", 1, 1.32827),
    ("x**4", 0.1, 0),
    ("sin(x)", 3, 3.14159265),
    ("exp(x) - 2", 0.5, 0.69314718),
]

for expr, x0, exact in test_cases:

    try:
        x_r, approx_error, num_iterations, steps = ModifiedNewtonRaphson(x0, expr, tol=1e-14, max_iter= 50, significantFigs=6)
        print(f"\nf(x) = {expr}, x0 = {x0}")
        print(f"  Computed root: {x_r}")
        print(f"  Expected root: {exact}")
        print(f"  Relative error: {abs(x_r - decimal.Decimal(str(exact)))}")
        print("approx_error: ", approx_error)
        print("num_iterations: ", num_iterations)
        for row in steps:
            print(row)
         
    except:
        print("Div by Zero")
# Out:
# f(x) = (x-1)**3, x0 = 0.5
#   Computed root: 1.00000
#   Expected root: 1
#   Relative error: 0.00000
# approx_error:  0
# num_iterations:  2
# {'iter': 1, 'x_old': Decimal('0.5'), 'x_new': Decimal('1.0'), 'error': Decimal('0.5')}
# {'iter': 2, 'x_old': Decimal('1.0'), 'x_new': Decimal('1.00000'), 'error': Decimal('0')}
#
# f(x) = x**2 - 4, x0 = 3
#   Computed root: 2.00000
#   Expected root: 2
#   Relative error: 0.00000
# approx_error:  0
# num_iterations:  5
# {'iter': 1, 'x_old': Decimal('3'), 'x_new': Decimal('1.84615'), 'error': Decimal('0.625003')}
# {'iter': 2, 'x_old': Decimal('1.84615'), 'x_new': Decimal('1.99361'), 'error': Decimal('0.0739663')}
# {'iter': 3, 'x_old': Decimal('1.99361'), 'x_new': Decimal('1.99999'), 'error': Decimal('0.00319002')}
# {'iter': 4, 'x_old': Decimal('1.99999'), 'x_new': Decimal('2.00000'), 'error': Decimal('0.000005')}
# {'iter': 5, 'x_old': Decimal('2.00000'), 'x_new': Decimal('2.00000'), 'error': Decimal('0')}
#
# f(x) = x**3 - 3*x**2 + 3*x - 1, x0 = 0
#   Computed root: 1
#   Expected root: 1
#   Relative error: 0
# approx_error:  1
# num_iterations:  1
# {'iter': 1, 'x_old': Decimal('0'), 'x_new': Decimal('1'), 'error': Decimal('1')}
#
# f(x) = x**3 + 2*x - 5, x0 = 1
#   Computed root: 1.32827
#   Expected root: 1.32827
#   Relative error: 0.00000
# approx_error:  0
# num_iterations:  4
# {'iter': 1, 'x_old': Decimal('1'), 'x_new': Decimal('1.27027'), 'error': Decimal('0.212766')}
# {'iter': 2, 'x_old': Decimal('1.27027'), 'x_new': Decimal('1.32642'), 'error': Decimal('0.0423320')}
# {'iter': 3, 'x_old': Decimal('1.32642'), 'x_new': Decimal('1.32827'), 'error': Decimal('0.00139279')}
# {'iter': 4, 'x_old': Decimal('1.32827'), 'x_new': Decimal('1.32827'), 'error': Decimal('0')}
#
# f(x) = x**4, x0 = 0.1
#   Computed root: 4.19161E-24
#   Expected root: 0
#   Relative error: 4.19161E-24
# approx_error:  0.333335
# num_iterations:  50
# {'iter': 1, 'x_old': Decimal('0.1000000000000000055511151231257827021181583404541015625'), 'x_new': Decimal('5.55112E-18'), 'error': Decimal('1.80144E+16')}
# {'iter': 2, 'x_old': Decimal('5.55112E-18'), 'x_new': Decimal('4.16334E-18'), 'error': Decimal('0.333333')}
# {'iter': 3, 'x_old': Decimal('4.16334E-18'), 'x_new': Decimal('3.12250E-18'), 'error': Decimal('0.333335')}
# {'iter': 4, 'x_old': Decimal('3.12250E-18'), 'x_new': Decimal('2.34188E-18'), 'error': Decimal('0.333330')}
# {'iter': 5, 'x_old': Decimal('2.34188E-18'), 'x_new': Decimal('1.75641E-18'), 'error': Decimal('0.333333')}
# {'iter': 6, 'x_old': Decimal('1.75641E-18'), 'x_new': Decimal('1.31731E-18'), 'error': Decimal('0.333331')}
# {'iter': 7, 'x_old': Decimal('1.31731E-18'), 'x_new': Decimal('9.87982E-19'), 'error': Decimal('0.333334')}
# {'iter': 8, 'x_old': Decimal('9.87982E-19'), 'x_new': Decimal('7.40986E-19'), 'error': Decimal('0.333334')}
# {'iter': 9, 'x_old': Decimal('7.40986E-19'), 'x_new': Decimal('5.55739E-19'), 'error': Decimal('0.333335')}
# {'iter': 10, 'x_old': Decimal('5.55739E-19'), 'x_new': Decimal('4.16804E-19'), 'error': Decimal('0.333334')}
# {'iter': 11, 'x_old': Decimal('4.16804E-19'), 'x_new': Decimal('3.12603E-19'), 'error': Decimal('0.333333')}
# {'iter': 12, 'x_old': Decimal('3.12603E-19'), 'x_new': Decimal('2.34452E-19'), 'error': Decimal('0.333335')}
# {'iter': 13, 'x_old': Decimal('2.34452E-19'), 'x_new': Decimal('1.75839E-19'), 'error': Decimal('0.333333')}
# {'iter': 14, 'x_old': Decimal('1.75839E-19'), 'x_new': Decimal('1.31879E-19'), 'error': Decimal('0.333336')}
# {'iter': 15, 'x_old': Decimal('1.31879E-19'), 'x_new': Decimal('9.89093E-20'), 'error': Decimal('0.333333')}
# {'iter': 16, 'x_old': Decimal('9.89093E-20'), 'x_new': Decimal('7.41820E-20'), 'error': Decimal('0.333333')}
# {'iter': 17, 'x_old': Decimal('7.41820E-20'), 'x_new': Decimal('5.56365E-20'), 'error': Decimal('0.333333')}
# {'iter': 18, 'x_old': Decimal('5.56365E-20'), 'x_new': Decimal('4.17274E-20'), 'error': Decimal('0.333333')}
# {'iter': 19, 'x_old': Decimal('4.17274E-20'), 'x_new': Decimal('3.12956E-20'), 'error': Decimal('0.333331')}
# {'iter': 20, 'x_old': Decimal('3.12956E-20'), 'x_new': Decimal('2.34717E-20'), 'error': Decimal('0.333333')}
# {'iter': 21, 'x_old': Decimal('2.34717E-20'), 'x_new': Decimal('1.76038E-20'), 'error': Decimal('0.333331')}
# {'iter': 22, 'x_old': Decimal('1.76038E-20'), 'x_new': Decimal('1.32028E-20'), 'error': Decimal('0.333338')}
# {'iter': 23, 'x_old': Decimal('1.32028E-20'), 'x_new': Decimal('9.90211E-21'), 'error': Decimal('0.333332')}
# {'iter': 24, 'x_old': Decimal('9.90211E-21'), 'x_new': Decimal('7.42658E-21'), 'error': Decimal('0.333334')}
# {'iter': 25, 'x_old': Decimal('7.42658E-21'), 'x_new': Decimal('5.56994E-21'), 'error': Decimal('0.333332')}
# {'iter': 26, 'x_old': Decimal('5.56994E-21'), 'x_new': Decimal('4.17745E-21'), 'error': Decimal('0.333335')}
# {'iter': 27, 'x_old': Decimal('4.17745E-21'), 'x_new': Decimal('3.13309E-21'), 'error': Decimal('0.333332')}
# {'iter': 28, 'x_old': Decimal('3.13309E-21'), 'x_new': Decimal('2.34982E-21'), 'error': Decimal('0.333332')}
# {'iter': 29, 'x_old': Decimal('2.34982E-21'), 'x_new': Decimal('1.76237E-21'), 'error': Decimal('0.333330')}
# {'iter': 30, 'x_old': Decimal('1.76237E-21'), 'x_new': Decimal('1.32178E-21'), 'error': Decimal('0.333331')}
# {'iter': 31, 'x_old': Decimal('1.32178E-21'), 'x_new': Decimal('9.91335E-22'), 'error': Decimal('0.333333')}
# {'iter': 32, 'x_old': Decimal('9.91335E-22'), 'x_new': Decimal('7.43501E-22'), 'error': Decimal('0.333334')}
# {'iter': 33, 'x_old': Decimal('7.43501E-22'), 'x_new': Decimal('5.57626E-22'), 'error': Decimal('0.333333')}
# {'iter': 34, 'x_old': Decimal('5.57626E-22'), 'x_new': Decimal('4.18219E-22'), 'error': Decimal('0.333335')}
# {'iter': 35, 'x_old': Decimal('4.18219E-22'), 'x_new': Decimal('3.13664E-22'), 'error': Decimal('0.333334')}
# {'iter': 36, 'x_old': Decimal('3.13664E-22'), 'x_new': Decimal('2.35248E-22'), 'error': Decimal('0.333333')}
# {'iter': 37, 'x_old': Decimal('2.35248E-22'), 'x_new': Decimal('1.76436E-22'), 'error': Decimal('0.333333')}
# {'iter': 38, 'x_old': Decimal('1.76436E-22'), 'x_new': Decimal('1.32327E-22'), 'error': Decimal('0.333333')}
# {'iter': 39, 'x_old': Decimal('1.32327E-22'), 'x_new': Decimal('9.92453E-23'), 'error': Decimal('0.333333')}
# {'iter': 40, 'x_old': Decimal('9.92453E-23'), 'x_new': Decimal('7.44340E-23'), 'error': Decimal('0.333333')}
# {'iter': 41, 'x_old': Decimal('7.44340E-23'), 'x_new': Decimal('5.58254E-23'), 'error': Decimal('0.333336')}
# {'iter': 42, 'x_old': Decimal('5.58254E-23'), 'x_new': Decimal('4.18690E-23'), 'error': Decimal('0.333335')}
# {'iter': 43, 'x_old': Decimal('4.18690E-23'), 'x_new': Decimal('3.14017E-23'), 'error': Decimal('0.333335')}
# {'iter': 44, 'x_old': Decimal('3.14017E-23'), 'x_new': Decimal('2.35513E-23'), 'error': Decimal('0.333332')}
# {'iter': 45, 'x_old': Decimal('2.35513E-23'), 'x_new': Decimal('1.76635E-23'), 'error': Decimal('0.333331')}
# {'iter': 46, 'x_old': Decimal('1.76635E-23'), 'x_new': Decimal('1.32476E-23'), 'error': Decimal('0.333336')}
# {'iter': 47, 'x_old': Decimal('1.32476E-23'), 'x_new': Decimal('9.93570E-24'), 'error': Decimal('0.333333')}
# {'iter': 48, 'x_old': Decimal('9.93570E-24'), 'x_new': Decimal('7.45177E-24'), 'error': Decimal('0.333334')}
# {'iter': 49, 'x_old': Decimal('7.45177E-24'), 'x_new': Decimal('5.58882E-24'), 'error': Decimal('0.333335')}
# {'iter': 50, 'x_old': Decimal('5.58882E-24'), 'x_new': Decimal('4.19161E-24'), 'error': Decimal('0.333335')}
#
# f(x) = sin(x), x0 = 3
#   Computed root: 3.14159
#   Expected root: 3.14159265
#   Relative error: 0.00000265
# approx_error:  0
# num_iterations:  3
# {'iter': 1, 'x_old': Decimal('3'), 'x_new': Decimal('3.13971'), 'error': Decimal('0.0444977')}
# {'iter': 2, 'x_old': Decimal('3.13971'), 'x_new': Decimal('3.14159'), 'error': Decimal('0.000598423')}
# {'iter': 3, 'x_old': Decimal('3.14159'), 'x_new': Decimal('3.14159'), 'error': Decimal('0')}
#
# f(x) = exp(x) - 2, x0 = 0.5
#   Computed root: 0.693147
#   Expected root: 0.69314718
#   Relative error: 1.8E-7
# approx_error:  0
# num_iterations:  4
# {'iter': 1, 'x_old': Decimal('0.5'), 'x_new': Decimal('0.675640'), 'error': Decimal('0.259961')}
# {'iter': 2, 'x_old': Decimal('0.675640'), 'x_new': Decimal('0.692995'), 'error': Decimal('0.0250435')}
# {'iter': 3, 'x_old': Decimal('0.692995'), 'x_new': Decimal('0.693147'), 'error': Decimal('0.000219290')}
# {'iter': 4, 'x_old': Decimal('0.693147'), 'x_new': Decimal('0.693147'), 'error': Decimal('0')}
